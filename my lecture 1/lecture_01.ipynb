# %% [markdown]
# there are
# <font size = "4">
# font size 4
#
# other text
# other text
# <font size = "10">
# font size 10

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print ("My name is Natalie")
# Out:
# My name is Natalie
